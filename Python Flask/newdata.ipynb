# %%
import pandas as pd

# %%
df = pd.read_csv('Resources/all_perth.csv')

# %%
df
# Out:
#                     ADDRESS          SUBURB   PRICE  BEDROOMS  BATHROOMS  \
# 0          11 Approach Road            Boya  605000         3          2
# 1            11 Mons Street        Ashfield  450000         4          2
# 2           12 Sowden Drive          Samson  495000         3          1
# 3           13 Donavon Rise         Murdoch  375000         4          2
# 4            13 Mons Street        Ashfield  439000         3          1
# ...                     ...             ...     ...       ...        ...
# 32059   93A Kathleen Street      Bassendean  550000         3          1
# 32060      95B Tamar Street         Palmyra  629000         3          1
# 32061        97a Edney Road    High Wycombe  480000         4          2
# 32062  99 San Javier Circle  Secret Harbour  754000         4          3
# 32063        9A Simeon Rise        Pearsall  422500         4          2
#
#        GARAGE  LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST  \
# ...

# %%
df['DATE_SOLD']=df.DATE_SOLD.apply(lambda x : x[:7])

# %%
df.insert(0, "ID", range(1, len(df)+1))

# %%
df.head()
# Out:
#    ID           ADDRESS    SUBURB   PRICE  BEDROOMS  BATHROOMS  GARAGE  \
# 0   1  11 Approach Road      Boya  605000         3          2     2.0
# 1   2    11 Mons Street  Ashfield  450000         4          2     1.0
# 2   3   12 Sowden Drive    Samson  495000         3          1     2.0
# 3   4   13 Donavon Rise   Murdoch  375000         4          2     2.0
# 4   5    13 Mons Street  Ashfield  439000         3          1     2.0
#
#    LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST       NEAREST_STN  \
# 0       2269         190      1975.0     19300   Midland Station
# 1        533         130      1999.0      8600  Ashfield Station
# 2        714         100      1982.0     14300   Murdoch Station
# 3        730         234      1988.0     12400   Murdoch Station
# 4        533         118      1999.0      8600  Ashfield Station
#
#    NEAREST_STN_DIST DATE_SOLD  POSTCODE   LATITUDE   LONGITUDE  \
# 0              6500   01-2011      6056 -31.921047  116.059873
# ...

# %%
df['POSTCODE'] = df['POSTCODE'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32064 entries, 0 to 32063
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                32064 non-null  int32
#  1   ADDRESS           32064 non-null  object
#  2   SUBURB            32064 non-null  object
#  3   PRICE             32064 non-null  int64
#  4   BEDROOMS          32064 non-null  int64
#  5   BATHROOMS         32064 non-null  int64
#  6   GARAGE            29924 non-null  float64
#  7   LAND_AREA         32064 non-null  int64
#  8   FLOOR_AREA        32064 non-null  int64
#  9   BUILD_YEAR        29047 non-null  float64
#  10  CBD_DIST          32064 non-null  int64
#  11  NEAREST_STN       32064 non-null  object
#  12  NEAREST_STN_DIST  32064 non-null  int64
#  13  DATE_SOLD         32064 non-null  object
#  14  POSTCODE          32064 non-null  object
#  15  LATITUDE          32064 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['ID', 'ADDRESS', 'SUBURB', 'PRICE', 'BEDROOMS', 'BATHROOMS', 'GARAGE',
#        'LAND_AREA', 'FLOOR_AREA', 'BUILD_YEAR', 'CBD_DIST', 'NEAREST_STN',
#        'NEAREST_STN_DIST', 'DATE_SOLD', 'POSTCODE', 'LATITUDE', 'LONGITUDE',
#        'NEAREST_SCH', 'NEAREST_SCH_DIST', 'NEAREST_SCH_RANK'],
#       dtype='object')

# %%
clean_data = df.drop(columns=['NEAREST_SCH_RANK', 'GARAGE', 'BUILD_YEAR','FLOOR_AREA','BEDROOMS','BATHROOMS','FLOOR_AREA','BUILD_YEAR','NEAREST_SCH_DIST','NEAREST_STN_DIST'])
clean_data.head()
# Out:
#    ID           ADDRESS    SUBURB   PRICE  LAND_AREA  CBD_DIST  \
# 0   1  11 Approach Road      Boya  605000       2269     19300
# 1   2    11 Mons Street  Ashfield  450000        533      8600
# 2   3   12 Sowden Drive    Samson  495000        714     14300
# 3   4   13 Donavon Rise   Murdoch  375000        730     12400
# 4   5    13 Mons Street  Ashfield  439000        533      8600
#
#         NEAREST_STN DATE_SOLD POSTCODE   LATITUDE   LONGITUDE  \
# 0   Midland Station   01-2011     6056 -31.921047  116.059873
# 1  Ashfield Station   01-2011     6054 -31.916110  115.939820
# 2   Murdoch Station   01-2011     6163 -32.069367  115.795660
# 3   Murdoch Station   01-2011     6150 -32.060980  115.830990
# 4  Ashfield Station   01-2011     6054 -31.916190  115.939910
#
#                    NEAREST_SCH
# 0   TREETOPS MONTESSORI SCHOOL
# 1  CYRIL JACKSON SENIOR CAMPUS
# 2       SETON CATHOLIC COLLEGE
# 3       CORPUS CHRISTI COLLEGE
# 4  CYRIL JACKSON SENIOR CAMPUS

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32064 entries, 0 to 32063
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           32064 non-null  int32
#  1   ADDRESS      32064 non-null  object
#  2   SUBURB       32064 non-null  object
#  3   PRICE        32064 non-null  int64
#  4   LAND_AREA    32064 non-null  int64
#  5   CBD_DIST     32064 non-null  int64
#  6   NEAREST_STN  32064 non-null  object
#  7   DATE_SOLD    32064 non-null  object
#  8   POSTCODE     32064 non-null  object
#  9   LATITUDE     32064 non-null  float64
#  10  LONGITUDE    32064 non-null  float64
#  11  NEAREST_SCH  32064 non-null  object
# dtypes: float64(2), int32(1), int64(3), object(6)
# memory usage: 2.8+ MB

# %%
clean_data.to_csv('Resources/clean_data.csv',index=False)
